# %%
import json
import pandas as pd
# Out:
# /var/folders/bc/tpckwg9j0g7cs8q7ntp4qrdw0000gn/T/ipykernel_38114/748694261.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
with open('data/e_coli_core.json', 'r') as f:
    m = json.load(f)

# %%
df = pd.DataFrame.from_records(m['reactions'])

# %%
df.head()
# Out:
#     id                           name  \
# 0  PFK            Phosphofructokinase
# 1  PFL         Pyruvate formate lyase
# 2  PGI  Glucose-6-phosphate isomerase
# 3  PGK        Phosphoglycerate kinase
# 4  PGL      6-phosphogluconolactonase
#
#                                          metabolites  lower_bound  \
# 0  {'adp_c': 1.0, 'atp_c': -1.0, 'f6p_c': -1.0, '...          0.0
# 1  {'accoa_c': 1.0, 'coa_c': -1.0, 'for_c': 1.0, ...          0.0
# 2                      {'f6p_c': 1.0, 'g6p_c': -1.0}      -1000.0
# 3  {'13dpg_c': 1.0, '3pg_c': -1.0, 'adp_c': 1.0, ...      -1000.0
# 4  {'6pgc_c': 1.0, '6pgl_c': -1.0, 'h2o_c': -1.0,...          0.0
#
#    upper_bound                                 gene_reaction_rule  \
# 0       1000.0                                     b3916 or b1723
# 1       1000.0  ((b0902 and b0903) and b2579) or (b0902 and b0...
# 2       1000.0                                              b4025
# 3       1000.0                                              b2926
# 4       1000.0                                              b0767
#
#                     subsystem                           notes  \
# 0  Glycolysis/Gluconeogenesis  {'original_bigg_ids': ['PFK']}
# 1         Pyruvate Metabolism  {'original_bigg_ids': ['PFL']}
# 2  Glycolysis/Gluconeogenesis  {'original_bigg_ids': ['PGI']}
# 3  Glycolysis/Gluconeogenesis  {'original_bigg_ids': ['PGK']}
# 4   Pentose Phosphate Pathway  {'original_bigg_ids': ['PGL']}
#
#                                           annotation  objective_coefficient
# 0  {'bigg.reaction': ['PFK'], 'ec-code': ['2.7.1....                    NaN
# 1  {'bigg.reaction': ['PFL'], 'biocyc': ['META:PY...                    NaN
# 2  {'bigg.reaction': ['PGI'], 'biocyc': ['META:PG...                    NaN
# 3  {'bigg.reaction': ['PGK'], 'biocyc': ['META:PH...                    NaN
# 4  {'bigg.reaction': ['PGL'], 'biocyc': ['META:6P...                    NaN

# %%
df.to_csv('data/e_coli_core_reactions.tsv', sep='\t', index=False)
