# %%
import json
import pandas as pd
# Out:
# /var/folders/bc/tpckwg9j0g7cs8q7ntp4qrdw0000gn/T/ipykernel_9436/748694261.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
with open('data/e_coli_core.json', 'r') as f:
    m = json.load(f)

# %%
df = pd.DataFrame.from_records(m['reactions'])

# %%
# df.head()

# %%
df.to_csv('data/e_coli_core_reactions.tsv', sep='\t', index=False)

# %%
met = pd.DataFrame.from_records(m["metabolites"])

# %%
df.to_csv('data/e_coli_core_metabolites.tsv', sep='\t', index=False)
