# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import brainshare

# %%
brainshare.login()
# Out:
# hello brainworld
